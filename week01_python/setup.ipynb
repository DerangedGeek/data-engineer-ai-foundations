# %% [markdown]
# Week 1 – Python Data Setup
# This notebook sets up the Python environment and verifies that all core
# libraries required for data engineering and AI workflows are working correctly.

# %%
import sys
print("Python version:", sys.version)
# Out:
# Python version: 3.14.0 (tags/v3.14.0:ebf955d, Oct  7 2025, 10:15:03) [MSC v.1944 64 bit (AMD64)]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

print("Pandas version:", pd.__version__)
print("NumPy version:", np.__version__)
# Out:
# Pandas version: 3.0.0
# NumPy version: 2.4.2

# %%
#environment test
import os
print("Current working directory:", os.getcwd())
print("List of files in the current directory:", os.listdir('.'))
# Out:
# Current working directory: c:\Users\micah\Documents\data-engineer-ai-foundation\week01_python
# List of files in the current directory: ['setup', 'setup.ipynb']

# %%
#Dataset test
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'Robert'],
    'Age': [25, 30, 45,29],
    'City': ['New York', 'Los Angeles', 'Chicago','Charlotte']
}
df= pd.DataFrame(data)
print("Sample DataFrame:")
print( df['Age'].mean(), "is the average age.")
# Out:
# Sample DataFrame:
# 32.25 is the average age.

# %%
#Data visualization test
df.plot(kind='bar', x='Name', y='Age', title='Age Distribution')
plt.show()
